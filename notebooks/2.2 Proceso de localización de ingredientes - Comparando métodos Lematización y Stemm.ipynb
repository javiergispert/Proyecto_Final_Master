# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt

from scipy.stats import trim_mean  
from scipy import stats
from scipy.stats import sem

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import nltk
from nltk import SnowballStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

import spacy

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
fuzz.partial_ratio("this is a test", "this is a test!")
# Out:
# 100

# %% [markdown]
# # Data Supermercados

# %%
df = pd.read_csv('../../../data/datamarket_clean_unique.csv')
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0        3233  https://www.dia.es/compra-online/productos/beb...
# 1        4593  https://www.carrefour.es/supermercado/pomelo-c...
# 2        4680  https://tienda.mercadona.es/product/9522/mini-...
# 3        5854  https://www.carrefour.es/supermercado/baguette...
# 4        5856  https://www.carrefour.es/supermercado/pan-de-m...
#
#     supermarket                                           category  \
# 0        dia-es        bebidas_isotonicas_y_energeticas_isotonicas
# 1  carrefour-es        el_mercado_frutas_naranjas_y_otros_citricos
# 2  mercadona-es                       cereales_y_galletas_cereales
# 3  carrefour-es  el_mercado_panaderia_bolleria_y_pasteleria_pan...
# 4  carrefour-es  el_mercado_panaderia_bolleria_y_pasteleria_pan...
#
#                                                 name  price  reference_price  \
# 0  POWERADE bebida refrescante aromatizada ice st...   1.39             2.78
# 1               Pomelo Círculo de Calidad 1 kg aprox   1.75             1.75
# 2  Mini cereales rellenos de chocolate y avellana...   1.30             7.43
# 3  Baguette precocida Carrefour pack de 2 unidade...   0.75             2.50
# 4  Pan de molde sin corteza Natural 100% Bimbo si...   2.30             5.11
#
#   reference_unit                        product_id        Date  \
# 0              l  79d9fe5ead25b3f5a8629a67af0f379e  2021-03-06
# 1             kg  6d8ad09c426320e638209da067f2e5f2  2021-03-06
# 2             kg  527837fde906593fa80458fd7a9b546e  2021-03-06
# 3             kg  a06071d024822fcf8e9d12ff897d7b8b  2021-03-06
# 4             kg  7e731ecb83c085e8583683cc228d1423  2021-03-06
#
#                                           name_lemma  \
# 0  poweradirbebidarefrescantearomatizadostormzero...
# 1                          pomelocírculocalidadaprox
# 2        minicerealrellenochocolateavellanahacendado
# 3              baguettirprecocidocarrefourpackunidad
# 4                     moldecortezanaturalbimbolactós
#
#                                     name_lemma_space  \
# 0  poweradir bebida refrescante aromatizado storm...
# 1                       pomelo círculo calidad aprox
# 2   mini cereal relleno chocolate avellana hacendado
# 3          baguettir precocido carrefour pack unidad
# 4                 molde corteza natural bimbo lactós
#
#                                 name_stemm  \
# 0  poweradbebrefrescaromatizstormzerbotell
# 1                    pomelcirculcalidaprox
# 2    minicerealrellenchocolatavellanhacend
# 3         baguettprecoccarrefourpackunidad
# 4              moldcorteznaturalbimblactos
#
#                                 name_stemm_space
# 0  powerad beb refresc aromatiz storm zer botell
# 1                       pomel circul calid aprox
# 2     mini cereal rellen chocolat avellan hacend
# 3           baguett precoc carrefour pack unidad
# 4                mold cortez natural bimb lactos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19386 entries, 0 to 19385
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        19386 non-null  int64
#  1   url               19386 non-null  object
#  2   supermarket       19386 non-null  object
#  3   category          19386 non-null  object
#  4   name              19386 non-null  object
#  5   price             19386 non-null  float64
#  6   reference_price   19386 non-null  float64
#  7   reference_unit    19383 non-null  object
#  8   product_id        19386 non-null  object
#  9   Date              19386 non-null  object
#  10  name_lemma        19384 non-null  object
#  11  name_lemma_space  19384 non-null  object
#  12  name_stemm        19385 non-null  object
#  13  name_stemm_space  19385 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 2.1+ MB

# %%
df_carrefour = df[df['supermarket']=='carrefour-es']
df_mercadona = df[df['supermarket']=='mercadona-es']
df_dia = df[df['supermarket']=='dia-es']

# %% [markdown]
# # Receta de cocina Test

# %% [markdown]
# ### Sin Tokenización ni Lemma ni Stemm

# %%
# Lentejas estofadas

lentejas_estofadas = '''350 g de lentejas castellanas secas
50 g de pimiento rojo en trozos 3-4 cm
50 g de pimiento verde en trozos 3-4 cm
50 g de zanahoria en trozos 3-4 cm
50 g de cebolleta en trozos 3-4 cm
o bien 50 g de cebolla en trozos 3-4 cm
25 g de aceite de oliva
1 cucharadita de sal
1 cucharadita de pimentón
1 pastilla de caldo de pollo
50 g de chorizo en rodajas
50 g de jamón curado en dados
900 g de agua'''

# %%
separador = '\n'

# %%
lentejas_estofadas_lst = lentejas_estofadas.split(separador)
lentejas_estofadas_lst
# Out:
# ['350 g de lentejas castellanas secas',
#  '50 g de pimiento rojo en trozos 3-4 cm',
#  '50 g de pimiento verde en trozos 3-4 cm',
#  '50 g de zanahoria en trozos 3-4 cm',
#  '50 g de cebolleta en trozos 3-4 cm',
#  'o bien 50 g de cebolla en trozos 3-4 cm',
#  '25 g de aceite de oliva',
#  '1 cucharadita de sal',
#  '1 cucharadita de pimentón',
#  '1 pastilla de caldo de pollo',
#  '50 g de chorizo en rodajas',
#  '50 g de jamón curado en dados',
#  '900 g de agua']

# %% [markdown]
# ### Con Tokenización, Lemma y Stemm

# %%
spanishstemmer=SnowballStemmer('spanish')

# %%
nlp = spacy.load('es_core_news_sm')
def normalize_lemma(text):
    doc = nlp(text)
    words = [t.orth_ for t in doc if not t.is_punct | t.is_stop]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    cadena = " ".join(lexical_tokens)
    doc2 = nlp(cadena)
    lemmas = [tok.lemma_.lower() for tok in doc2 if tok.pos_ != 'PRON']
    lemmas_cadena = "".join(lemmas)
    return lemmas_cadena
ingr_lemma = normalize_lemma('350 g de lentejas castellanas secas')
ingr_lemma
# Out:
# 'lentejacastellanoseco'

# %%
recipe_lemma = []
for i in lentejas_estofadas_lst:
    recipe_lemma.append(normalize_lemma(i))
recipe_lemma
# Out:
# ['lentejacastellanoseco',
#  'pimientorojotrozo',
#  'pimientoverdetrozo',
#  'zanahoriartrozo',
#  'cebolletartrozo',
#  'cebollartrozo',
#  'aceiteolivo',
#  'cucharaditar',
#  'cucharaditarpimentón',
#  'pastillacaldopollo',
#  'chorizorodaja',
#  'jamóncuradodado',
#  'agua']

# %%
def normalize_lemma_space(text):
    doc = nlp(text)
    words = [t.orth_ for t in doc if not t.is_punct | t.is_stop]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    cadena = " ".join(lexical_tokens)
    doc2 = nlp(cadena)
    lemmas = [tok.lemma_.lower() for tok in doc2 if tok.pos_ != 'PRON']
    lemmas_cadena = " ".join(lemmas)
    return lemmas_cadena

# %%
recipe_lemma_space = []
for i in lentejas_estofadas_lst:
    recipe_lemma_space.append(normalize_lemma_space(i))
recipe_lemma_space
# Out:
# ['lenteja castellano seco',
#  'pimiento rojo trozo',
#  'pimiento verde trozo',
#  'zanahoriar trozo',
#  'cebolletar trozo',
#  'cebollar trozo',
#  'aceite olivo',
#  'cucharaditar',
#  'cucharaditar pimentón',
#  'pastilla caldo pollo',
#  'chorizo rodaja',
#  'jamón curado dado',
#  'agua']

# %%
def normalize_stemm(text):
    doc = nlp(text)
    words = [t.orth_ for t in doc if not t.is_punct | t.is_stop]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    stems = [spanishstemmer.stem(token) for token in lexical_tokens]
    stems_cadena = "".join(stems)
    return stems_cadena
ingr_stemm = normalize_stemm('350 g de lentejas castellanas secas')
ingr_stemm
# Out:
# 'lentejcastellansec'

# %%
recipe_stemm = []
for i in lentejas_estofadas_lst:
    recipe_stemm.append(normalize_stemm(i))
recipe_stemm
# Out:
# ['lentejcastellansec',
#  'pimientrojtroz',
#  'pimientverdtroz',
#  'zanahoritroz',
#  'cebollettroz',
#  'cebolltroz',
#  'aceitoliv',
#  'cucharadit',
#  'cucharaditpimenton',
#  'pastillcaldpoll',
#  'chorizrodaj',
#  'jamoncurdad',
#  'agu']

# %%
def normalize_stemm_space(text):
    doc = nlp(text)
    words = [t.orth_ for t in doc if not t.is_punct | t.is_stop]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    stems = [spanishstemmer.stem(token) for token in lexical_tokens]
    stems_cadena = " ".join(stems)
    return stems_cadena

# %%
recipe_stemm_space = []
for i in lentejas_estofadas_lst:
    recipe_stemm_space.append(normalize_stemm_space(i))
recipe_stemm_space
# Out:
# ['lentej castellan sec',
#  'pimient roj troz',
#  'pimient verd troz',
#  'zanahori troz',
#  'cebollet troz',
#  'ceboll troz',
#  'aceit oliv',
#  'cucharadit',
#  'cucharadit pimenton',
#  'pastill cald poll',
#  'choriz rodaj',
#  'jamon cur dad',
#  'agu']

# %% [markdown]
# # Creación de tablas de productos intermedias

# %% [markdown]
# ### Dia

# %%
df_dia.reset_index(drop=True, inplace=True)

# %%
df_dia.loc[(df_dia['Date']=='2022-10-16') & 
                 (df_dia['name'].str.lower().str.contains('agua', na=False)),
                 ['name','category', 'product_id', 'price', 'reference_price', 'reference_unit','Date', 'url']]
# Out:
#                                                    name  \
# 2423       AQUABONA agua mineral natural botella 1.5 lt
# 3497      FONT VELLA agua mineral natural botella 75 cl
# 3498         PERRIER agua mineral con gas botella 50 cl
# 3499  AQUAREL agua mineral natural botella tapón spo...
# 3500            DIA agua mineral natural botella 1.5 lt
# 3501              FONT VELLA agua con gas botella 50 cl
# 3503  SAN BENEDETTO agua mineral con frutos rojos ze...
# 3524      FONT VELLA agua mineral natural botella 33 cl
# 3525             DIA agua mineral con gas botella 50 cl
# 3526  URSU9 agua mineral natural alcalina ph9 botell...
# 3527              DIA agua mineral natural botella 5 lt
# 3529           DIA agua mineral natural botella 1.25 lt
# 3530         AQUABONA agua mineral natural botella 5 lt
# 3531    FONT VELLA agua mineral natural botella 6.25 lt
# 3532   SAN PELLEGRINO agua mineral con gas botella 1 lt
# 3533  LANJARON agua mineral natural botella tapón sp...
# 3534        AQUAREL agua mineral natural botella 1.5 lt
# 3535  AQUAREL agua mineral natural botella tapón spo...
# 3536           FONTER agua mineral con gas botella 1 lt
# 4296      LA ESPAÑOLA aceite de aguacate botella 250 ml
# 4871      FONT VELLA agua mineral natural botella 50 cl
# 4872       FONT VELLA agua mineral natural botella 1 lt
# 5225                   Pulpa de aguacate tarrina 125 gr
# 5227                            Aguacate bandeja 450 gr
# 5228                        Aguacate bio bandeja 400 gr
# 5261                    Aguacate unidad (440 gr aprox.)
# 5649  SOLAN DE CABRAS agua mineral natural botella 5...
# 5651             DIA agua mineral natural botella 50 cl
# 5652          AQUAREL agua mineral natural botella 5 lt
# 5653       LANJARON agua mineral natural botella 1.5 lt
# 5654  FONT VELLA agua mineral natural botella tapón ...
# 5655             DIA agua mineral natural botella 33 cl
# 5656         AQUAREL agua mineral natural botella 50 cl
# 5657  SOLAN DE CABRAS agua mineral natural botella 5 lt
# 5658    VICHY CATALAN agua mineral con gas botella 1 lt
# 5659            DIA agua mineral con gas botella 1.5 lt
# 5686  SOLAN DE CABRAS agua mineral natural botella 1...
# 5687       FONT VELLA agua mineral natural botella 2 lt
# 5688      CABREIROA agua mineral natural botella 1.5 lt
# 5689     FONT VELLA agua mineral natural botella 1.5 lt
#
#                                         category  \
# 2423                               bebidas_aguas
# 3497                               bebidas_aguas
# 3498                               bebidas_aguas
# 3499                               bebidas_aguas
# 3500                               bebidas_aguas
# 3501                               bebidas_aguas
# 3503                               bebidas_aguas
# 3524                               bebidas_aguas
# 3525                               bebidas_aguas
# 3526                               bebidas_aguas
# 3527                               bebidas_aguas
# 3529                               bebidas_aguas
# 3530                               bebidas_aguas
# 3531                               bebidas_aguas
# 3532                               bebidas_aguas
# 3533                               bebidas_aguas
# 3534                               bebidas_aguas
# 3535                               bebidas_aguas
# 3536                               bebidas_aguas
# 4296  despensa_aceites_vinagres_y_alinos_aceites
# 4871                               bebidas_aguas
# 4872                               bebidas_aguas
# 5225            frescos_frutas_frutas_tropicales
# 5227            frescos_frutas_frutas_tropicales
# 5228            frescos_frutas_frutas_tropicales
# 5261            frescos_frutas_frutas_tropicales
# 5649                               bebidas_aguas
# 5651                               bebidas_aguas
# 5652                               bebidas_aguas
# 5653                               bebidas_aguas
# 5654                               bebidas_aguas
# 5655                               bebidas_aguas
# 5656                               bebidas_aguas
# 5657                               bebidas_aguas
# 5658                               bebidas_aguas
# 5659                               bebidas_aguas
# 5686                               bebidas_aguas
# 5687                               bebidas_aguas
# 5688                               bebidas_aguas
# 5689                               bebidas_aguas
#
#                             product_id  price  reference_price reference_unit  \
# 2423  5a0a1bb342bf791eb3296626d0dc88ec   0.59             0.39              l
# 3497  95eda25354f7042d89e9a5a62b7d0997   0.85             1.13              l
# 3498  e3f82915d0e511d191369e9421816e54   0.99             1.98              l
# 3499  f55d7e4d9d72a784c5000a5ac289f07e   0.75             1.00              l
# 3500  c2790645ef08d7603f9acb25ecc96f70   0.21             0.14              l
# 3501  786237374abdc5ac351843ec3f27efca   0.89             1.78              l
# 3503  bf17830fc8a382f4acfb6e11e4af2c2d   0.89             2.23              l
# 3524  d9283465c949711c49f8ef616e1c55bf   0.69             2.09              l
# 3525  7f7091e11c8f3aefac750483054f2b03   0.21             0.42              l
# 3526  ada53c07a9e76b480b39d8a5825a1543   0.69             0.46              l
# 3527  dfd7f8125c7be270258910f5dd606aed   0.55             0.11              l
# 3529  ac48e2dadbece5ae76b712adeb95a847   0.36             0.29              l
# 3530  4070e21a09c737626f0ef259d57e2680   1.29             0.26              l
# 3531  d9fada35a8d3d7874b222f004b29a5a9   2.19             0.35              l
# 3532  cd10adb08333f0d4414f552919cdc16f   1.29             1.29              l
# 3533  889c83fa81fc605edfe14c2f8fe5c7a0   0.56             1.70              l
# 3534  092fe8e5f16922197a00f5acb973faff   0.59             0.39              l
# 3535  f8b5171a197b49ec89b80ecb9cc1f7e4   0.55             1.67              l
# 3536  47b5239e786bb21579e580ee8688c021   1.19             1.19              l
# 4296  014d05e1dc0ded9cc77af5a9e53d252c   5.99            23.96              l
# 4871  c69a55aec463d0a9c18494708e8d37bc   0.65             1.30              l
# 4872  7c93725c28f0038116639fc6a63d286e   0.69             0.69              l
# 5225  1f6e9f71d5565e78cd58f949babd47cd   1.55            12.40             kg
# 5227  f6c3acbade287c74bead8deca1f60220   1.99             4.42             kg
# 5228  8192a89426af334581ecc36e19cade32   2.69             6.73             kg
# 5261  db30acfdf2636806638b968d64a89ac2   1.76             3.99             kg
# 5649  178ff42fcf2ebdd1e38ae1477e3a3d61   0.69             1.38              l
# 5651  34d7b9f9d64d3579ed800d5b7f2db8c6   0.22             0.44              l
# 5652  bd1ac576497a39f69cdf2462b015314f   1.49             0.30              l
# 5653  293c2482c986669df8ef2da4c389cc0c   0.69             0.46              l
# 5654  08bbc20c14bde8873fa69c84531fa23c   0.55             1.67              l
# 5655  69ff3732147475b79b929eb28df5738b   0.27             0.82              l
# 5656  44a3281a028f72469b012253e9805e5c   0.59             1.18              l
# 5657  1f25de9a3a095afca2e646bd0f0fe612   2.29             0.46              l
# 5658  1e68d4f7456d3c1901b46cd2f9cd4920   1.35             1.35              l
# 5659  f987bec3b028e2c26915a9e44a18f196   0.38             0.25              l
# 5686  25ca80747ce1c7e7ca65445daafb6262   0.79             0.53              l
# 5687  ce2f0c1b03e891e8001d79bfaf549cab   0.89             0.45              l
# 5688  e6ba0481c192803356b3e07cd24474c6   0.79             0.53              l
# 5689  dc944418a7187f38880b2622fde297d6   0.69             0.46              l
#
#             Date                                                url
# 2423  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3497  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3498  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3499  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3500  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3501  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3503  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3524  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3525  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3526  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3527  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3529  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3530  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3531  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3532  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3533  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3534  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3535  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 3536  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 4296  2022-10-16  https://www.dia.es/compra-online/despensa/acei...
# 4871  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 4872  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5225  2022-10-16  https://www.dia.es/compra-online/frescos/fruta...
# 5227  2022-10-16  https://www.dia.es/compra-online/frescos/fruta...
# 5228  2022-10-16  https://www.dia.es/compra-online/frescos/fruta...
# 5261  2022-10-16  https://www.dia.es/compra-online/frescos/fruta...
# 5649  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5651  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5652  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5653  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5654  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5655  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5656  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5657  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5658  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5659  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5686  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5687  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5688  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...
# 5689  2022-10-16  https://www.dia.es/compra-online/bebidas/aguas...

# %%
df_dia.iloc[3147]['url']
# Out:
# 'https://www.dia.es/compra-online/frescos/charcuteria-y-quesos/curados/p/274059'

# %%
a_dia = {'b26d51cb5be3aff71a71f87c8908b846' : 'Lentejas', 
         'dada7a323f98cbb8abd3b7a65f11da13' : 'pimiento verde', 
         '3b118605318ccdf76e4db430ef53f94c' : 'pimiento rojo',
         '6d854922c4f8a5a5740991f3e7108da0' : 'zanahoria',
         '06690951566cb9affcb7b886db944225': 'cebolleta dulce', 
         '9dff07cb2f5875147d574f3cd2eb52d7' : 'cebolla',
         'ff4bec68a3103927d5568c80482a6c54' : 'aceite de oliva virgen extra',
         '9e6edc9fb8588e953a8177db9c5fa2c5' : 'aceite de oliva',
         'e453450e28331ea2f9d7b32f423f0ae0': 'sal fina',
         '213ebf1ba8e25da18f50e6770a6fb2bb': 'pimentón',
         '068082a32f9ba83d41c4db0df5087004': 'pastilla de caldo de pollo',
         '616df75e8d66ded901d003e282c3e062' : 'caldo de pollo',
         '26b1a3be138796cd829876975f1d1b01' : 'chorizo',
         '640a8ef50612a09e27d47a75f8ac10f4' : 'jamón curado en dados',
         'c2790645ef08d7603f9acb25ecc96f70' : 'agua'}

# %% [markdown]
# ### Carrefour

# %%
df_carrefour.reset_index(drop=True, inplace=True)

# %%
df_carrefour.loc[(df_carrefour['Date']=='2022-10-16') & 
                 (df_carrefour['name'].str.lower().str.contains('pimi', na=False)),
                 ['name','category', 'product_id', 'price', 'reference_price', 'reference_unit','Date', 'url']]
# Out:
#                                                    name  \
# 6740              Pimienta negra molida Carrefour 45 g.
# 6841  Relleno para fajitas de pimientos, pollo y ceb...
# 7334      Pimiento del piquillo entero Carrefour 225 g.
# 7451  Pimiento del piquillo relleno de bacalao conge...
# 7528         Paté a la pimienta Casa Tarradellas 125 g.
#
#                                                category  \
# 6740    la_despensa_alimentacion_especias_y_sazonadores
# 6841  la_despensa_conservas_sopas_y_precocinados_pla...
# 7334  la_despensa_conservas_sopas_y_precocinados_con...
# 7451  productos_frescos_pescaderia_preparados_y_elab...
# 7528  productos_frescos_charcuteria_foie_pates_y_sob...
#
#                             product_id  price  reference_price reference_unit  \
# 6740  127a3fc17b8bac1dfdb47ed6438d9e30   0.62            13.78             kg
# 6841  0995776c87859933bb0f8b3da70b26b6   1.55             5.17             kg
# 7334  004d6b13bdbfa5ba4945c9d645de3af9   0.94             4.18             kg
# 7451  9481892e04c1d46395598662cfa99fc0   4.20            10.50             kg
# 7528  e0364995a83690a57e419de7379b6216   1.09             8.72             kg
#
#             Date                                                url
# 6740  2022-10-16  https://www.carrefour.es/supermercado/pimienta...
# 6841  2022-10-16  https://www.carrefour.es/supermercado/relleno-...
# 7334  2022-10-16  https://www.carrefour.es/supermercado/pimiento...
# 7451  2022-10-16  https://www.carrefour.es/supermercado/pimiento...
# 7528  2022-10-16  https://www.carrefour.es/supermercado/pate-a-l...

# %%
df_carrefour.iloc[7334]['url']
# Out:
# 'https://www.carrefour.es/supermercado/pimiento-del-piquillo-entero-carrefour-225-g/R-526539373/p'

# %%
a_carrefour = {'7d751158fe2567a81e991a0a572ce83f' : 'Lentejas', 
               '' : 'pimiento verde', 
               '' : 'pimiento rojo',
               '53e9f777e840fd172ee8bae9747d61f6' : 'zanahoria',
               '452cf4289710f6cb5edb3607fc646185': 'cebolleta dulce', 
               '9d368b1cf54fbb93051b576c09753663' : 'cebolla',
               'ec7cf862264cec9b1bc8344574840325' : 'aceite de oliva virgen extra',
               '276a2380dabc5045fcd8a869f60b88fc' : 'aceite de oliva',
               '': 'sal fina',
               '': 'pimentón',
               '': 'pastilla de caldo de pollo',
               'c33ea2b6f4582b4e4c0579520bb41bcc' : 'caldo de pollo',
               '411367289ea7cb6032db7d65f7286bf4' : 'chorizo',
               '' : 'jamón curado en dados',
               '97dc915b2efecc4be9db3d93635c4c19' : 'agua'}

# %% [markdown]
# ### Mercadona

# %%
df_mercadona.reset_index(drop=True, inplace=True)

# %%
df_mercadona.loc[(df_mercadona['Date']=='2022-10-16') & (df_mercadona['name'].str.lower().str.contains('agua mineral grande', na=False)),
                 ['name','category', 'product_id', 'price', 'reference_price', 'reference_unit','Date', 'url']]
# Out:
#                                      name               category  \
# 1860           Agua mineral grande Bezoya  agua_y_refrescos_agua
# 1861   Agua mineral grande Nestlé Aquarel  agua_y_refrescos_agua
# 1862   Agua mineral grande Nestlé Aquarel  agua_y_refrescos_agua
# 1864  Agua mineral grande Solán de Cabras  agua_y_refrescos_agua
# 1865         Agua mineral grande Lanjarón  agua_y_refrescos_agua
# 1866          Agua mineral grande Aguadoy  agua_y_refrescos_agua
# 1867          Agua mineral grande Aguadoy  agua_y_refrescos_agua
# 1871         Agua mineral grande Fondetal  agua_y_refrescos_agua
# 1874          Agua mineral grande Liviana  agua_y_refrescos_agua
# 1889           Agua mineral grande Bezoya  agua_y_refrescos_agua
# 1890   Agua mineral grande Nestlé Aquarel  agua_y_refrescos_agua
# 1892  Agua mineral grande Solán de Cabras  agua_y_refrescos_agua
# 1893         Agua mineral grande Lanjarón  agua_y_refrescos_agua
# 1894          Agua mineral grande Aguadoy  agua_y_refrescos_agua
# 1895          Agua mineral grande Aguadoy  agua_y_refrescos_agua
# 1899         Agua mineral grande Fondetal  agua_y_refrescos_agua
# 1902          Agua mineral grande Liviana  agua_y_refrescos_agua
#
#                             product_id  price  reference_price reference_unit  \
# 1860  7b5c061bb6ad5e8331e04cb847c9cb94   3.96            0.440              l
# 1861  e8b2239a25e2b131601db3746e575fd0   1.45            0.290              l
# 1862  b66786dccd32c5ce538c2378c1ceeac9   0.54            0.360              l
# 1864  239e582e89b1fe70e40b2875f47999c4   0.79            0.527              l
# 1865  cca0beef13b0412b6bb6bbf845986163   0.69            0.460              l
# 1866  19362795c2f1f7a4d87236b5d88a82ab   0.63            0.105              l
# 1867  c1e1a4c9d0af6984f9c1da705b025be1   0.19            0.127              l
# 1871  72b70a2c8a9f58910067b70e38778184   0.32            0.214              l
# 1874  749a61b49de83b28d5a93e87d2ff0976   0.66            0.330              l
# 1889  6bf5ce45fbcc18b2d213edd196b26884   0.66            0.440              l
# 1890  6bdd5f5ebe8d9980f11bd11995a4d57f   3.24            0.360              l
# 1892  482636e438dff608ea6ba6553f28f229   4.56            0.507              l
# 1893  c807967027d73445a0dc349f1da68a4c   3.96            0.440              l
# 1894  f90118693b9526249dce87f5c7783ecf   0.73            0.092              l
# 1895  866b27114ca94dec30cff27fb890675c   1.14            0.127              l
# 1899  2c4f2bee048ea2b722ef61c725a5d8b7   1.92            0.214              l
# 1902  d0d975aefae16a2240bbc327ad291bb8   3.96            0.330              l
#
#             Date                                                url
# 1860  2022-10-16  https://tienda.mercadona.es/product/27314/agua...
# 1861  2022-10-16  https://tienda.mercadona.es/product/27052/agua...
# 1862  2022-10-16  https://tienda.mercadona.es/product/27232/agua...
# 1864  2022-10-16  https://tienda.mercadona.es/product/27356/agua...
# 1865  2022-10-16  https://tienda.mercadona.es/product/27216/agua...
# 1866  2022-10-16  https://tienda.mercadona.es/product/27398/agua...
# 1867  2022-10-16  https://tienda.mercadona.es/product/28472/agua...
# 1871  2022-10-16  https://tienda.mercadona.es/product/23634/agua...
# 1874  2022-10-16  https://tienda.mercadona.es/product/27208/agua...
# 1889  2022-10-16  https://tienda.mercadona.es/product/27230/agua...
# 1890  2022-10-16  https://tienda.mercadona.es/product/27099/agua...
# 1892  2022-10-16  https://tienda.mercadona.es/product/27327/agua...
# 1893  2022-10-16  https://tienda.mercadona.es/product/27291/agua...
# 1894  2022-10-16  https://tienda.mercadona.es/product/28482/agua...
# 1895  2022-10-16  https://tienda.mercadona.es/product/28471/agua...
# 1899  2022-10-16  https://tienda.mercadona.es/product/23633/agua...
# 1902  2022-10-16  https://tienda.mercadona.es/product/27202/agua...

# %%
df_mercadona.iloc[1862]['url']
# Out:
# 'https://tienda.mercadona.es/product/27232/agua-mineral-grande-nestle-aquarel-mineralizacion-muy-debil-botella'

# %%
a_mercadona = {'ecb81249f1dea9150ee04ed7a178029e' : 'Lentejas', 
               'c71150390be4bd6853c9449a8cff62eb' : 'pimiento verde', 
               '43c81c10c1d9eb52b2410de54f274c9d' : 'pimiento rojo',
               'c0ac3da899e51308db2492c91aebbcb2' : 'zanahoria',
               'b2b8c39d71440a4cba62b86f31ce15e7': 'cebolleta dulce', 
               '2f4a5c7049e822ce171768cde7bd2e76' : 'cebolla',
               '488e146ef0d8864d12b7ea721d8de22a' : 'aceite de oliva virgen extra',
               'e4b0fed91e0f81060e98ed076ebe39e4' : 'aceite de oliva',
               '14efd535d750388baa8122354a3bf2ff': 'sal fina',
               '370579b0cb90786d050efc5026103a3f': 'pimentón',
               '74270a2e828834e1dc65088ac8947be5': 'pastilla de caldo de pollo',
               '9161c686d13e241ab7af3f7ef1c191b0' : 'caldo de pollo',
               '4cb684b2f6a44a7d56f7d49b0a265f17' : 'chorizo',
               'f06a69f6ac8f49bfb052af3e0f614998' : 'jamón curado en dados',
               'c1e1a4c9d0af6984f9c1da705b025be1' : 'agua'}

# %% [markdown]
# # Probando Localizar un ingrediente

# %% [markdown]
# ### Método exacto

# %%
def get_key(val):
    # list out keys and values separately
    key_list = list(a_mercadona.keys())
    val_list = list(a_mercadona.values())
        
    ratios = process.extractOne(val , a_mercadona)
    if int(ratios[1]) > 80: # can play with this number 
        position = val_list.index(ratios[0])
        return [key_list[position], ratios[0], ratios[1]]
 
    return ['No product_ID', 'No product Match', 'No product Match']

# %%
get_key('50 g de pimiento verde en trozos 3-4 cm')
# Out:
# ['c71150390be4bd6853c9449a8cff62eb', 'pimiento verde', 90]

# %%
def get_recipe_id(recipe_list):
    product_id = []
    match = []
    probabilities = []
    price = []
    exact_price = []
    name = []
    
    for i in recipe_list:
        product_id.append(get_key(i)[0])
        match.append(get_key(i)[1])
        probabilities.append(get_key(i)[2])
        price.append(df_mercadona[df_mercadona.product_id==get_key(i)[0]].price.squeeze())
        name.append(df_mercadona[df_mercadona.product_id==get_key(i)[0]].name.iloc[0])
        
    # buscamos el precio exacto en base al gramaje    
        gr = word_tokenize(i, language='spanish')
        if gr[1] == 'g':
            x = (int(gr[0])/1000) * df_mercadona[df_mercadona.product_id==get_key(i)[0]].reference_price.squeeze()
        elif gr[1] == 'kg':
            x = int(gr[0]) * df_mercadona[df_mercadona.product_id==get_key(i)[0]].reference_price.squeeze()
        elif gr[1] == 'l':
            x = int(gr[0]) * df_mercadona[df_mercadona.product_id==get_key(i)[0]].reference_price.squeeze()
        elif gr[1] == 'cucharadita':
            x = (int(gr[0])*0.005) * df_mercadona[df_mercadona.product_id==get_key(i)[0]].reference_price.squeeze()
        elif gr[1] == 'cucharada':
            x = (int(gr[0])*0.075) * df_mercadona[df_mercadona.product_id==get_key(i)[0]].reference_price.squeeze()
        elif gr[1] == 'pellizco':
            x = (int(gr[0])*0.001) * df_mercadona[df_mercadona.product_id==get_key(i)[0]].reference_price.squeeze()
        else:
            x = 0
        exact_price.append(round(x, 3))
        
    # creamos el dataframe con todos los ingredientes de la receta    
    df = pd.DataFrame({
        'originals': recipe_list,
        'potential matches': match,
        'product_id': product_id,
        'probability of match': probabilities,
        'original_name_exact': name,
        'price_exact': price,
        'price_exact_gr': exact_price})
    return df

# %%
px_receta = get_recipe_id(lentejas_estofadas_lst)
px_receta
# Out:
#                                   originals           potential matches  \
# 0       350 g de lentejas castellanas secas                    Lentejas
# 1    50 g de pimiento rojo en trozos 3-4 cm               pimiento rojo
# 2   50 g de pimiento verde en trozos 3-4 cm              pimiento verde
# 3        50 g de zanahoria en trozos 3-4 cm                   zanahoria
# 4        50 g de cebolleta en trozos 3-4 cm             cebolleta dulce
# 5   o bien 50 g de cebolla en trozos 3-4 cm                     cebolla
# 6                   25 g de aceite de oliva             aceite de oliva
# 7                      1 cucharadita de sal                    sal fina
# 8                 1 cucharadita de pimentón                    pimentón
# 9              1 pastilla de caldo de pollo  pastilla de caldo de pollo
# 10               50 g de chorizo en rodajas                     chorizo
# 11            50 g de jamón curado en dados       jamón curado en dados
# 12                            900 g de agua                        agua
#
#                           product_id  probability of match  \
# 0   ecb81249f1dea9150ee04ed7a178029e                    90
# 1   43c81c10c1d9eb52b2410de54f274c9d                    90
# 2   c71150390be4bd6853c9449a8cff62eb                    90
# 3   c0ac3da899e51308db2492c91aebbcb2                    90
# 4   b2b8c39d71440a4cba62b86f31ce15e7                    86
# 5   2f4a5c7049e822ce171768cde7bd2e76                    90
# 6   e4b0fed91e0f81060e98ed076ebe39e4                    90
# 7   14efd535d750388baa8122354a3bf2ff                    86
# 8   370579b0cb90786d050efc5026103a3f                    90
# 9   74270a2e828834e1dc65088ac8947be5                    96
# 10  4cb684b2f6a44a7d56f7d49b0a265f17                    90
# 11  f06a69f6ac8f49bfb052af3e0f614998                    95
# 12  c1e1a4c9d0af6984f9c1da705b025be1                    90
#
#                       original_name_exact  price_exact  price_exact_gr
# 0                       Lenteja Hacendado         1.60           0.560
# 1                           Pimiento rojo         0.81           0.134
# 2                          Pimiento verde         0.62           0.114
# 3                              Zanahorias         0.69           0.069
# 4                         Cebollas dulces         1.99           0.100
# 5                                Cebollas         1.35           0.000
# 6        Aceite de oliva virgen Hacendado         4.20           0.105
# 7                      Sal fina Hacendado         0.25           0.001
# 8                Pimentón dulce Hacendado         0.80           0.071
# 9   Caldo de pollo Hacendado en pastillas         1.00           0.000
# 10          Chorizo dulce extra Hacendado         1.89           0.338
# 11           Taquitos de jamón Incarlopsa         2.32           0.580
# 12            Agua mineral grande Aguadoy         0.19           0.114

# %%
print('El precio de esta receta es de:', round(px_receta['price_exact_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra de esta receta es:', round(px_receta['price_exact'].sum(), 2), '€')
# Out:
# El precio de esta receta es de: 2.19 €
# El precio de la cesta de la compra de esta receta es: 17.71 €

# %% [markdown]
# ### Con Lemma

# %%
recipe_lemma
# Out:
# ['lentejacastellanoseco',
#  'pimientorojotrozo',
#  'pimientoverdetrozo',
#  'zanahoriartrozo',
#  'cebolletartrozo',
#  'cebollartrozo',
#  'aceiteolivo',
#  'cucharaditar',
#  'cucharaditarpimentón',
#  'pastillacaldopollo',
#  'chorizorodaja',
#  'jamóncuradodado',
#  'agua']

# %%
def match_lists(list1, list2, recipe):
    matches = []
    probabilities = []
    name = []
    price = []
    exact_price = []

    for i in list1:
        ratios = process.extractOne(i, list2)
        ratios_recipe = process.extractOne(i, recipe)

        if int(ratios[1]) > 50: # can play with this number
            matches.append(ratios[0])
            probabilities.append(ratios[1])
        else:
            matches.append('no match')
            probabilities.append('probability was too low')
            
        name.append(df_mercadona[df_mercadona.name_lemma==ratios[0]].name.iloc[0])
        price.append(df_mercadona[df_mercadona.name_lemma==ratios[0]].price.iloc[0].squeeze())
        
    # buscamos el precio exacto en base al gramaje    
        gr = word_tokenize(ratios_recipe[0], language='spanish')
        if gr[1] == 'g':
            x = (int(gr[0])/1000) * df_mercadona[df_mercadona.name_lemma==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'kg':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_lemma==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'l':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_lemma==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharadita':
            x = (int(gr[0])*0.005) * df_mercadona[df_mercadona.name_lemma==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharada':
            x = (int(gr[0])*0.075) * df_mercadona[df_mercadona.name_lemma==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'pellizco':
            x = (int(gr[0])*0.001) * df_mercadona[df_mercadona.name_lemma==ratios[0]].reference_price.iloc[0].squeeze()
        else:
            x = 0
        exact_price.append(round(x, 3))

    df = pd.DataFrame({
        'originals': lentejas_estofadas_lst,
        'lemma_recipe': list1,
        'potential matches': matches,
        'probability of match': probabilities,
        'original_name_lemma': name,
        'price_lemma': price,
        'price_lemma_gr': exact_price
    }

    )

    return df

# %%
df_lemma = match_lists(recipe_lemma, df_mercadona['name_lemma'].tolist(), lentejas_estofadas_lst)
df_lemma
# Out:
#                                   originals           lemma_recipe  \
# 0       350 g de lentejas castellanas secas  lentejacastellanoseco
# 1    50 g de pimiento rojo en trozos 3-4 cm      pimientorojotrozo
# 2   50 g de pimiento verde en trozos 3-4 cm     pimientoverdetrozo
# 3        50 g de zanahoria en trozos 3-4 cm        zanahoriartrozo
# 4        50 g de cebolleta en trozos 3-4 cm        cebolletartrozo
# 5   o bien 50 g de cebolla en trozos 3-4 cm          cebollartrozo
# 6                   25 g de aceite de oliva            aceiteolivo
# 7                      1 cucharadita de sal           cucharaditar
# 8                 1 cucharadita de pimentón   cucharaditarpimentón
# 9              1 pastilla de caldo de pollo     pastillacaldopollo
# 10               50 g de chorizo en rodajas          chorizorodaja
# 11            50 g de jamón curado en dados        jamóncuradodado
# 12                            900 g de agua                   agua
#
#                           potential matches  probability of match  \
# 0                                   semilla                    64
# 1                              pimientorojo                    83
# 2                             pimientoverde                    84
# 3                                 zanahoria                    90
# 4                                   cebolla                    77
# 5                                   cebolla                    90
# 6            aceiteolivovirgenextraeminente                    90
# 7                                      yuca                    68
# 8                                     mento                    72
# 9                                     pollo                    90
# 10  zanahoriarrodajahacendadoultracongelado                    69
# 11               puntajamóncuradoincarlopsa                    71
# 12          aguamineralpequeñonestléaquarel                    90
#
#                            original_name_lemma  price_lemma  price_lemma_gr
# 0                        Pan con semillas 4,5%         1.50           1.500
# 1                                Pimiento rojo         0.81           0.134
# 2                               Pimiento verde         0.62           0.114
# 3                                   Zanahorias         0.85           0.042
# 4                                     Cebollas         1.35           0.068
# 5                                     Cebollas         1.35           0.000
# 6        Aceite de oliva virgen extra Eminente        13.00           0.065
# 7                                         Yuca         1.91           0.014
# 8                                        Menta         1.25           0.031
# 9                                  Medio pollo         3.15           0.000
# 10  Zanahoria rodajas Hacendado ultracongelada         1.05           0.070
# 11           Puntas de jamón curado Incarlopsa         1.63           0.325
# 12         Agua mineral pequeña Nestlé Aquarel         2.10           0.955

# %%
print('El precio de esta receta es de:', round(df_lemma['price_lemma_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra de esta receta es:', round(df_lemma['price_lemma'].sum(), 2), '€')
# Out:
# El precio de esta receta es de: 3.32 €
# El precio de la cesta de la compra de esta receta es: 30.57 €

# %%
recipe_lemma_space
# Out:
# ['lenteja castellano seco',
#  'pimiento rojo trozo',
#  'pimiento verde trozo',
#  'zanahoriar trozo',
#  'cebolletar trozo',
#  'cebollar trozo',
#  'aceite olivo',
#  'cucharaditar',
#  'cucharaditar pimentón',
#  'pastilla caldo pollo',
#  'chorizo rodaja',
#  'jamón curado dado',
#  'agua']

# %%
def match_lists_space(list1, list2, recipe):
    matches = []
    probabilities = []
    name = []
    price = []
    exact_price = []

    for i in list1:
        ratios = process.extractOne(i, list2)
        ratios_recipe = process.extractOne(i, recipe)

        if int(ratios[1]) > 50: # can play with this number
            matches.append(ratios[0])
            probabilities.append(ratios[1])
        else:
            matches.append('no match')
            probabilities.append('probability was too low')
            
        name.append(df_mercadona[df_mercadona.name_lemma_space==ratios[0]].name.iloc[0])
        price.append(df_mercadona[df_mercadona.name_lemma_space==ratios[0]].price.iloc[0].squeeze())
        
    # buscamos el precio exacto en base al gramaje    
        gr = word_tokenize(ratios_recipe[0], language='spanish')
        if gr[1] == 'g':
            x = (int(gr[0])/1000) * df_mercadona[df_mercadona.name_lemma_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'kg':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_lemma_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'l':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_lemma_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharadita':
            x = (int(gr[0])*0.005) * df_mercadona[df_mercadona.name_lemma_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharada':
            x = (int(gr[0])*0.075) * df_mercadona[df_mercadona.name_lemma_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'pellizco':
            x = (int(gr[0])*0.001) * df_mercadona[df_mercadona.name_lemma_space==ratios[0]].reference_price.iloc[0].squeeze()
        else:
            x = 0
        exact_price.append(round(x, 3))

    df = pd.DataFrame({
        'originals': lentejas_estofadas_lst,
        'lemma_recipe': list1,
        'potential matches': matches,
        'probability of match': probabilities,
        'original_name_lemma_space': name,
        'price_lemma_space': price,
        'price_lemma_space_gr': exact_price
    }

    )

    return df

# %%
df_lemma_space = match_lists_space(recipe_lemma_space, df_mercadona['name_lemma_space'].tolist(), lentejas_estofadas_lst)
df_lemma_space
# Out:
#                                   originals             lemma_recipe  \
# 0       350 g de lentejas castellanas secas  lenteja castellano seco
# 1    50 g de pimiento rojo en trozos 3-4 cm      pimiento rojo trozo
# 2   50 g de pimiento verde en trozos 3-4 cm     pimiento verde trozo
# 3        50 g de zanahoria en trozos 3-4 cm         zanahoriar trozo
# 4        50 g de cebolleta en trozos 3-4 cm         cebolletar trozo
# 5   o bien 50 g de cebolla en trozos 3-4 cm           cebollar trozo
# 6                   25 g de aceite de oliva             aceite olivo
# 7                      1 cucharadita de sal             cucharaditar
# 8                 1 cucharadita de pimentón    cucharaditar pimentón
# 9              1 pastilla de caldo de pollo     pastilla caldo pollo
# 10               50 g de chorizo en rodajas           chorizo rodaja
# 11            50 g de jamón curado en dados        jamón curado dado
# 12                            900 g de agua                     agua
#
#                                  potential matches  probability of match  \
# 0                                  anís seco regio                    86
# 1                                    pimiento rojo                    95
# 2                                   pimiento verde                    95
# 3                                        zanahoria                    90
# 4                         pollo entero filet trozo                    86
# 5                                          cebolla                    90
# 6               aceite olivo virgen extra eminente                    90
# 7                                             yuca                    68
# 8   queso madurado cabro pimentón vera villa noble                    86
# 9                             caldo pollo pastilla                    95
# 10                       aceituna hacendado rodaja                    86
# 11                  jamón reservar cortado máquina                    86
# 12                       hummus aguacate hacendado                    90
#
#                             original_name_lemma_space  price_lemma_space  \
# 0                                     Anís seco Regio               7.45
# 1                                       Pimiento rojo               0.81
# 2                                      Pimiento verde               0.62
# 3                                          Zanahorias               0.85
# 4                       Pollo entero filetes y trozos               5.48
# 5                                            Cebollas               1.35
# 6               Aceite de oliva virgen extra Eminente              13.00
# 7                                                Yuca               1.91
# 8   Queso madurado de cabra con pimentón de la Ver...               5.33
# 9                         Caldo de pollo en pastillas               0.82
# 10                     Aceitunas Hacendado en rodajas               1.00
# 11               Jamón gran reserva cortado a máquina               2.52
# 12                       Hummus de aguacate Hacendado               1.70
#
#     price_lemma_space_gr
# 0                  2.608
# 1                  0.134
# 2                  0.114
# 3                  0.042
# 4                  0.182
# 5                  0.000
# 6                  0.065
# 7                  0.014
# 8                  0.065
# 9                  0.000
# 10                 0.588
# 11                 1.050
# 12                 7.650

# %%
print('El precio de esta receta es de:', round(df_lemma_space['price_lemma_space_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra de esta receta es:', round(df_lemma_space['price_lemma_space'].sum(), 2), '€')
# Out:
# El precio de esta receta es de: 12.51 €
# El precio de la cesta de la compra de esta receta es: 42.84 €

# %% [markdown]
# ### Con Stemm

# %%
recipe_stemm
# Out:
# ['lentejcastellansec',
#  'pimientrojtroz',
#  'pimientverdtroz',
#  'zanahoritroz',
#  'cebollettroz',
#  'cebolltroz',
#  'aceitoliv',
#  'cucharadit',
#  'cucharaditpimenton',
#  'pastillcaldpoll',
#  'chorizrodaj',
#  'jamoncurdad',
#  'agu']

# %%
def match_lists_stemm(list1, list2, recipe):
    matches = []
    probabilities = []
    name = []
    price = []
    exact_price = []

    for i in list1:
        ratios = process.extractOne(i, list2)
        ratios_recipe = process.extractOne(i, recipe)

        if int(ratios[1]) > 50: # can play with this number
            matches.append(ratios[0])
            probabilities.append(ratios[1])
        else:
            matches.append('no match')
            probabilities.append('probability was too low')
            
        name.append(df_mercadona[df_mercadona.name_stemm==ratios[0]].name.iloc[0])
        price.append(df_mercadona[df_mercadona.name_stemm==ratios[0]].price.iloc[0].squeeze())
        
    # buscamos el precio exacto en base al gramaje    
        gr = word_tokenize(ratios_recipe[0], language='spanish')
        if gr[1] == 'g':
            x = (int(gr[0])/1000) * df_mercadona[df_mercadona.name_stemm==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'kg':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_stemm==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'l':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_stemm==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharadita':
            x = (int(gr[0])*0.005) * df_mercadona[df_mercadona.name_stemm==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharada':
            x = (int(gr[0])*0.075) * df_mercadona[df_mercadona.name_stemm==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'pellizco':
            x = (int(gr[0])*0.001) * df_mercadona[df_mercadona.name_stemm==ratios[0]].reference_price.iloc[0].squeeze()
        else:
            x = 0
        exact_price.append(round(x, 3))

    df = pd.DataFrame({
        'originals': lentejas_estofadas_lst,
        'lemma_recipe': list1,
        'potential matches': matches,
        'probability of match': probabilities,
        'original_name_stemm': name,
        'price_stemm': price,
        'price_stemm_gr': exact_price
    }

    )

    return df

# %%
df_stemm = match_lists_stemm(recipe_stemm, df_mercadona['name_stemm'].tolist(), lentejas_estofadas_lst)
df_stemm
# Out:
#                                   originals        lemma_recipe  \
# 0       350 g de lentejas castellanas secas  lentejcastellansec
# 1    50 g de pimiento rojo en trozos 3-4 cm      pimientrojtroz
# 2   50 g de pimiento verde en trozos 3-4 cm     pimientverdtroz
# 3        50 g de zanahoria en trozos 3-4 cm        zanahoritroz
# 4        50 g de cebolleta en trozos 3-4 cm        cebollettroz
# 5   o bien 50 g de cebolla en trozos 3-4 cm          cebolltroz
# 6                   25 g de aceite de oliva           aceitoliv
# 7                      1 cucharadita de sal          cucharadit
# 8                 1 cucharadita de pimentón  cucharaditpimenton
# 9              1 pastilla de caldo de pollo     pastillcaldpoll
# 10               50 g de chorizo en rodajas         chorizrodaj
# 11            50 g de jamón curado en dados         jamoncurdad
# 12                            900 g de agua                 agu
#
#                  potential matches  probability of match  \
# 0                           castañ                    72
# 1                              piñ                    90
# 2                              piñ                    90
# 3                         zanahori                    90
# 4                           ceboll                    90
# 5                           ceboll                    90
# 6        aceitolivvirgextraeminent                    90
# 7            turronchocolatsuchard                    64
# 8                             ment                    90
# 9                             poll                    90
# 10  zanahorirodajhacendultracongel                    74
# 11                             moñ                    90
# 12                     baguettglut                    90
#
#                            original_name_stemm  price_stemm  price_stemm_gr
# 0                                     Castañas         3.99           1.396
# 1                                         Piña         2.25           0.068
# 2                                         Piña         2.25           0.068
# 3                                   Zanahorias         0.85           0.042
# 4                                     Cebollas         1.35           0.068
# 5                                     Cebollas         1.35           0.068
# 6        Aceite de oliva virgen extra Eminente        13.00           0.065
# 7                  Turrón de chocolate Suchard         3.30           0.063
# 8                                        Menta         1.25           0.031
# 9                                  Medio pollo         3.15           0.000
# 10  Zanahoria rodajas Hacendado ultracongelada         1.05           0.070
# 11                                    Pan moño         1.45           0.145
# 12                         Baguette sin gluten         1.70           8.739

# %%
print('El precio de esta receta es de:', round(df_stemm['price_stemm_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra de esta receta es:', round(df_stemm['price_stemm'].sum(), 2), '€')
# Out:
# El precio de esta receta es de: 10.82 €
# El precio de la cesta de la compra de esta receta es: 36.94 €

# %%
recipe_stemm_space
# Out:
# ['lentej castellan sec',
#  'pimient roj troz',
#  'pimient verd troz',
#  'zanahori troz',
#  'cebollet troz',
#  'ceboll troz',
#  'aceit oliv',
#  'cucharadit',
#  'cucharadit pimenton',
#  'pastill cald poll',
#  'choriz rodaj',
#  'jamon cur dad',
#  'agu']

# %%
def match_lists_stemm_space(list1, list2, recipe):
    matches = []
    probabilities = []
    name = []
    price = []
    exact_price = []

    for i in list1:
        ratios = process.extractOne(i, list2)
        ratios_recipe = process.extractOne(i, recipe)

        if int(ratios[1]) > 50: # can play with this number
            matches.append(ratios[0])
            probabilities.append(ratios[1])
        else:
            matches.append('no match')
            probabilities.append('probability was too low')
            
        name.append(df_mercadona[df_mercadona.name_stemm_space==ratios[0]].name.iloc[0])
        price.append(df_mercadona[df_mercadona.name_stemm_space==ratios[0]].price.iloc[0].squeeze())
        
    # buscamos el precio exacto en base al gramaje    
        gr = word_tokenize(ratios_recipe[0], language='spanish')
        if gr[1] == 'g':
            x = (int(gr[0])/1000) * df_mercadona[df_mercadona.name_stemm_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'kg':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_stemm_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'l':
            x = int(gr[0]) * df_mercadona[df_mercadona.name_stemm_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharadita':
            x = (int(gr[0])*0.005) * df_mercadona[df_mercadona.name_stemm_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'cucharada':
            x = (int(gr[0])*0.075) * df_mercadona[df_mercadona.name_stemm_space==ratios[0]].reference_price.iloc[0].squeeze()
        elif gr[1] == 'pellizco':
            x = (int(gr[0])*0.001) * df_mercadona[df_mercadona.name_stemm_space==ratios[0]].reference_price.iloc[0].squeeze()
        else:
            x = 0
        exact_price.append(round(x, 3))

    df = pd.DataFrame({
        'originals': lentejas_estofadas_lst,
        'lemma_recipe': list1,
        'potential matches': matches,
        'probability of match': probabilities,
        'original_name_stemm_space': name,
        'price_stemm_space': price,
        'price_stemm_space_gr': exact_price
    }

    )

    return df

# %%
df_stemm_space = match_lists_stemm_space(recipe_stemm_space, df_mercadona['name_stemm_space'].tolist(), lentejas_estofadas_lst)
df_stemm_space
# Out:
#                                   originals          lemma_recipe  \
# 0       350 g de lentejas castellanas secas  lentej castellan sec
# 1    50 g de pimiento rojo en trozos 3-4 cm      pimient roj troz
# 2   50 g de pimiento verde en trozos 3-4 cm     pimient verd troz
# 3        50 g de zanahoria en trozos 3-4 cm         zanahori troz
# 4        50 g de cebolleta en trozos 3-4 cm         cebollet troz
# 5   o bien 50 g de cebolla en trozos 3-4 cm           ceboll troz
# 6                   25 g de aceite de oliva            aceit oliv
# 7                      1 cucharadita de sal            cucharadit
# 8                 1 cucharadita de pimentón   cucharadit pimenton
# 9              1 pastilla de caldo de pollo     pastill cald poll
# 10               50 g de chorizo en rodajas          choriz rodaj
# 11            50 g de jamón curado en dados         jamon cur dad
# 12                            900 g de agua                   agu
#
#                 potential matches  probability of match  \
# 0                   anis sec regi                    86
# 1                     pimient roj                    95
# 2                    pimient verd                    95
# 3                        zanahori                    90
# 4                          ceboll                    90
# 5                          ceboll                    90
# 6   aceit oliv virg extra eminent                    90
# 7         turron chocolat suchard                    64
# 8                            ment                    90
# 9               cald poll pastill                    95
# 10           aceitun hacend rodaj                    86
# 11                            moñ                    90
# 12                   baguett glut                    90
#
#                 original_name_stemm_space  price_stemm_space  \
# 0                         Anís seco Regio               7.45
# 1                           Pimiento rojo               0.81
# 2                          Pimiento verde               0.62
# 3                              Zanahorias               0.85
# 4                                Cebollas               1.35
# 5                                Cebollas               1.35
# 6   Aceite de oliva virgen extra Eminente              13.00
# 7             Turrón de chocolate Suchard               3.30
# 8                                   Menta               1.25
# 9             Caldo de pollo en pastillas               0.82
# 10         Aceitunas Hacendado en rodajas               1.00
# 11                               Pan moño               1.45
# 12                    Baguette sin gluten               1.70
#
#     price_stemm_space_gr
# 0                  2.608
# 1                  0.134
# 2                  0.114
# 3                  0.042
# 4                  0.000
# 5                  0.068
# 6                  0.065
# 7                  0.063
# 8                  0.031
# 9                  0.000
# 10                 0.588
# 11                 0.145
# 12                 8.739

# %%
print('El precio de esta receta es de:', round(df_stemm_space['price_stemm_space_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra de esta receta es:', round(df_stemm_space['price_stemm_space'].sum(), 2), '€')
# Out:
# El precio de esta receta es de: 12.6 €
# El precio de la cesta de la compra de esta receta es: 34.95 €

# %%
df_merge_compare = pd.merge(px_receta[['originals', 'original_name_exact']], 
                            df_lemma[['originals', 'original_name_lemma']], on=['originals'])
df_merge_compare = pd.merge(df_merge_compare, df_lemma_space[['originals', 'original_name_lemma_space']], on=['originals'])
df_merge_compare = pd.merge(df_merge_compare, df_stemm[['originals', 'original_name_stemm']], on=['originals'])
df_merge_compare = pd.merge(df_merge_compare, df_stemm_space[['originals', 'original_name_stemm_space']], on=['originals'])
df_merge_compare
# Out:
#                                   originals  \
# 0       350 g de lentejas castellanas secas
# 1    50 g de pimiento rojo en trozos 3-4 cm
# 2   50 g de pimiento verde en trozos 3-4 cm
# 3        50 g de zanahoria en trozos 3-4 cm
# 4        50 g de cebolleta en trozos 3-4 cm
# 5   o bien 50 g de cebolla en trozos 3-4 cm
# 6                   25 g de aceite de oliva
# 7                      1 cucharadita de sal
# 8                 1 cucharadita de pimentón
# 9              1 pastilla de caldo de pollo
# 10               50 g de chorizo en rodajas
# 11            50 g de jamón curado en dados
# 12                            900 g de agua
#
#                       original_name_exact  \
# 0                       Lenteja Hacendado
# 1                           Pimiento rojo
# 2                          Pimiento verde
# 3                              Zanahorias
# 4                         Cebollas dulces
# 5                                Cebollas
# 6        Aceite de oliva virgen Hacendado
# 7                      Sal fina Hacendado
# 8                Pimentón dulce Hacendado
# 9   Caldo de pollo Hacendado en pastillas
# 10          Chorizo dulce extra Hacendado
# 11           Taquitos de jamón Incarlopsa
# 12            Agua mineral grande Aguadoy
#
#                            original_name_lemma  \
# 0                        Pan con semillas 4,5%
# 1                                Pimiento rojo
# 2                               Pimiento verde
# 3                                   Zanahorias
# 4                                     Cebollas
# 5                                     Cebollas
# 6        Aceite de oliva virgen extra Eminente
# 7                                         Yuca
# 8                                        Menta
# 9                                  Medio pollo
# 10  Zanahoria rodajas Hacendado ultracongelada
# 11           Puntas de jamón curado Incarlopsa
# 12         Agua mineral pequeña Nestlé Aquarel
#
#                             original_name_lemma_space  \
# 0                                     Anís seco Regio
# 1                                       Pimiento rojo
# 2                                      Pimiento verde
# 3                                          Zanahorias
# 4                       Pollo entero filetes y trozos
# 5                                            Cebollas
# 6               Aceite de oliva virgen extra Eminente
# 7                                                Yuca
# 8   Queso madurado de cabra con pimentón de la Ver...
# 9                         Caldo de pollo en pastillas
# 10                     Aceitunas Hacendado en rodajas
# 11               Jamón gran reserva cortado a máquina
# 12                       Hummus de aguacate Hacendado
#
#                            original_name_stemm  \
# 0                                     Castañas
# 1                                         Piña
# 2                                         Piña
# 3                                   Zanahorias
# 4                                     Cebollas
# 5                                     Cebollas
# 6        Aceite de oliva virgen extra Eminente
# 7                  Turrón de chocolate Suchard
# 8                                        Menta
# 9                                  Medio pollo
# 10  Zanahoria rodajas Hacendado ultracongelada
# 11                                    Pan moño
# 12                         Baguette sin gluten
#
#                 original_name_stemm_space
# 0                         Anís seco Regio
# 1                           Pimiento rojo
# 2                          Pimiento verde
# 3                              Zanahorias
# 4                                Cebollas
# 5                                Cebollas
# 6   Aceite de oliva virgen extra Eminente
# 7             Turrón de chocolate Suchard
# 8                                   Menta
# 9             Caldo de pollo en pastillas
# 10         Aceitunas Hacendado en rodajas
# 11                               Pan moño
# 12                    Baguette sin gluten

# %%
print('El precio por el método exacto es de:', round(px_receta['price_exact_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra por el método exacto es:', round(px_receta['price_exact'].sum(), 2), '€ \n'), 

print('El precio por el método lemma es de:', round(df_lemma['price_lemma_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra por el método lemma es:', round(df_lemma['price_lemma'].sum(), 2), '€ \n')

print('El precio por el método lemma_space es de:', round(df_lemma_space['price_lemma_space_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra por el método lemma_space es:', round(df_lemma_space['price_lemma_space'].sum(), 2), '€ \n')

print('El precio por el método stemm es de:', round(df_stemm['price_stemm_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra de esta receta es:', round(df_stemm['price_stemm'].sum(), 2), '€ \n')

print('El precio por el método stemm_space es de:', round(df_stemm_space['price_stemm_space_gr'].sum(), 2), '€')
print('El precio de la cesta de la compra por el método stemm_space es:', round(df_stemm_space['price_stemm_space'].sum(), 2), '€ \n')
# Out:
# El precio por el método exacto es de: 2.19 €
# El precio de la cesta de la compra por el método exacto es: 17.71 €
#
# El precio por el método lemma es de: 3.32 €
# El precio de la cesta de la compra por el método lemma es: 30.57 €
#
# El precio por el método lemma_space es de: 12.51 €
# El precio de la cesta de la compra por el método lemma_space es: 42.84 €
#
# El precio por el método stemm es de: 10.82 €
# El precio de la cesta de la compra de esta receta es: 36.94 €
#
# El precio por el método stemm_space es de: 12.6 €
# El precio de la cesta de la compra por el método stemm_space es: 34.95 €
